# %%
""" 
Analyzing the different types of domain shifts between source and target graphs. 
We investigate feature shift, structural shift, and hybrid shift scenarios.
"""

# %%
from utils.train_utils.mmd import MMD
from utils.train_utils.mmd2 import MMD2

from data.build_dataset import build_dataset
from models.build_model import build_model
from utils.train_utils.metrics import BaseMetric

from experiments.ablation.shifts import test

# %%
test()
# Out:
# 1
